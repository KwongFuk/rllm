# %%
from rllm.data.dataset import DatasetRegistry

# %%
test_dataset = DatasetRegistry.load_dataset("MathVision", "test")

# %%
sample = test_dataset[0]
print("\n📦 第一个样本内容:")
for key, value in sample.items():
    print(f"{key}: {value}\n")
# Out:
# 📦 第一个样本内容:
# id: 4
#
# question: How many different digits can you find in this picture?
# <image1>
#
# options: []
#
# image: images/4.jpg
#
# ...

# %%
hotpotdataset = DatasetRegistry.load_dataset("hotpotqa", "test")

# %%
sample = hotpotdataset[0]

print("\n📦 第一个样本内容:")
for key, value in sample.items():
    print(f"{key}: {value}\n")
# Out:
# 📦 第一个样本内容:
# question: Were Scott Derrickson and Ed Wood of the same nationality?
#
# ground_truth: yes
#
# data_source: hotpotqa
